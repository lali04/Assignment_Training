# %% [markdown]
# <a href="https://colab.research.google.com/github/lali04/Assignment_Training/blob/main/Web_scraping_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url="https://www.imdb.com/chart/top/"

# %%
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language":"en-US,en;q=0.9"
}

# %%
response=requests.get(url, headers=headers)

# %%
print("status:",response.status_code)
# Out:
# status: 200

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
movies=soup.find_all("li",class_="ipc-metadata-list-summary-item")
print(f"Movie Count :{len(movies)}")
# Out:
# Movie Count :25

# %%
data=[]
for m in movies:
  title_t=m.find("h3", class_="ipc-title__text")
  title=title_t.text.strip() if title_t else "NA"

  rank_t=m.find("div", class_="ipc-signpost__text")
  rank=rank_t.text.split("#")[1] if rank_t else "NA"

  year_t=m.find("span", class_="sc-a55f6282-6 iMumIM cli-title-metadata-item")
  year=year_t.text.strip() if year_t else "NA"

  rating_t=m.find("span", class_="ipc-rating-star--rating")
  rating=rating_t.text.strip() if rating_t else "NA"

  data.append(
      {
        "Title":title,
        "Rank":rank,
        "Year":year,
        "Rating":rating
      })
df=pd.DataFrame(data)
print(df.head())
# Out:
#                       Title Rank  Year Rating
# 0  The Shawshank Redemption    1  1994    9.3
# 1             The Godfather    2  1972    9.2
# 2           The Dark Knight    3  2008    9.1
# 3     The Godfather Part II    4  1974    9.0
# 4              12 Angry Men    5  1957    9.0

# %%
df.to_csv("Web_scraped_IMDB_file.csv",index=False)
print("Saved Successfully")
# Out:
# Saved Successfully
